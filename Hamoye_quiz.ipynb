# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#read the dataset and check the first 5 rows
data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding ='latin-1')
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#check number of rows and columns
data.shape
# Out:
# (60943, 12)

# %%
#check other info about the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
#check unique items in Item column
data.Item.nunique()
# Out:
# 119

# %%
#get the summary statistics of this data
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#check for missing values
data.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#divide the missing value in 2016 by the number of 2016
1535/data.Y2016.count()
# Out:
# 0.02583827093994075

# %%
#check for correlation
data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
#checking for value counts of Element Code
data.Element.value_counts()
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
data_import = data[data['Element'] == 'Import Quantity']
data_import
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 12             4   Algeria       2905  Cereals - Excluding Beer          5611
# 28             4   Algeria       2511        Wheat and products          5611
# 44             4   Algeria       2805         Rice and products          5611
# 59             4   Algeria       2513       Barley and products          5611
# 74             4   Algeria       2514        Maize and products          5611
# ...          ...       ...        ...                       ...           ...
# 60897        181  Zimbabwe       2769   Aquatic Animals, Others          5611
# 60905        181  Zimbabwe       2775            Aquatic Plants          5611
# 60913        181  Zimbabwe       2928             Miscellaneous          5611
# 60923        181  Zimbabwe       2680               Infant food          5611
# 60933        181  Zimbabwe       2899             Miscellaneous          5611
#
# ...

# %%
data_import[['Y2014','Y2015','Y2016','Y2017']].sum()
# Out:
# Y2014    274144.48
# Y2015    267018.46
# Y2016    286582.78
# Y2017    294559.09
# dtype: float64

# %%
data_prod = data[data['Element'] == 'Production']

# %%
data_prod[['Y2014','Y2015','Y2016','Y2017']].sum()
# Out:
# Y2014    1931287.75
# Y2015    1947019.39
# Y2016    1943537.15
# Y2017    2030056.89
# dtype: float64

# %%
data_18 =  data[['Element','Y2018']]

# %%
data_18.Element.value_counts()
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
data.Area.nunique()
# Out:
# 49

# %%
data_algeria = data_import[data_import['Area'] == 'Algeria']

# %%
data_algeria.Y2018.sum()
# Out:
# 36238.29
